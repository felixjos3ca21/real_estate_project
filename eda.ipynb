# %% [markdown]
# # Proyecto Inmobiliaria

# %%
# importar librerías
import pandas as pd
import fastparquet

# opción para ver todas las columnas
pd.set_option('display.max_columns', 500)

# %% [markdown]
# ### Primera Parte (ETL)

# %%
# carga de la data
df_test = pd.read_parquet("data/test.parquet")
df_train = pd.read_parquet("data/train.parquet")

# %%
# visualizar primeros registros
df_test.head(2)
# Out:
#            id                                                url     region  \
# 0  7037609789  https://annarbor.craigslist.org/apa/d/wixom-ho...  ann arbor
# 1  7032406876  https://vermont.craigslist.org/apa/d/randolph-...    vermont
#
#                         region_url          type  sqfeet  beds  baths  \
# 0  https://annarbor.craigslist.org  manufactured    1344     3    2.0
# 1   https://vermont.craigslist.org     apartment    1050     2    1.0
#
#    cats_allowed  dogs_allowed  smoking_allowed  wheelchair_access  \
# 0             0             0                1                  0
# 1             0             0                1                  0
#
#    electric_vehicle_charge  comes_furnished laundry_options  \
# 0                        0                0     w/d in unit
# 1                        0                0     w/d hookups
#
#       parking_options                                          image_url  \
# 0  off-street parking  https://images.craigslist.org/00M0M_iNczP1nzIL...
# 1  off-street parking  https://images.craigslist.org/00L0L_ecirmYBIzL...
#
#                                          description      lat     long state
# 0  OPEN HOUSE TODAY! APPLY THIS WEEK, PUT A HOLDI...  42.5333 -83.5763    mi
# 1  Think of it, you'll be first to get your mail....  43.9393 -72.5538    vt

# %%
# visualizar primeros registros
df_train.head(2)
# Out:
#            id                                                url  \
# 0  7048013474  https://boise.craigslist.org/apa/d/very-nice-b...
# 1  7043931179  https://cosprings.craigslist.org/apa/d/colorad...
#
#              region                        region_url  price       type  \
# 0             boise      https://boise.craigslist.org   1350      house
# 1  colorado springs  https://cosprings.craigslist.org   1115  apartment
#
#    sqfeet  beds  baths  cats_allowed  dogs_allowed  smoking_allowed  \
# 0    1200     2    2.0             1             1                1
# 1     694     1    1.0             1             1                1
#
#    wheelchair_access  electric_vehicle_charge  comes_furnished  \
# 0                  0                        0                0
# 1                  0                        0                0
#
#   laundry_options  parking_options  \
# 0     w/d in unit  detached garage
# 1     w/d in unit          carport
#
#                                            image_url  \
# 0  https://images.craigslist.org/00B0B_cPiJMEheZe...
# 1  https://images.craigslist.org/00R0R_5XAoSKvfrz...
#
#                                          description      lat     long state
# 0  Super cute row house in the Boise bench area. ...  43.5851 -116.225    id
# 1  Windtree Apartment Homes currently has a spaci...  38.9137 -104.780    co

# %%
# función para obtener datos varios de los dataframe(info, describe, null, duplicated)
def print_df_info(df):

    print("** Info - Información general **")
    print(df.info())

    print("=======================================================")

    print("** Shape **")
    print(f"Filas: {df.shape[0]} - Columnas: {df.shape[1]}")

    print("=======================================================")

    print("** Describe - Estadísticas resumidas **")
    print(df.describe().T)

    print("=======================================================")

    print("** NaN - Nulos **")
    print(df.isna().sum())

    print("=======================================================")
    print("** Duplicated - Duplicados **")
    print(df.duplicated().sum())

# %%
print_df_info(df_test)
# Out:
# ** Info - Información general **
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38498 entries, 0 to 38497
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       38498 non-null  int64
#  1   url                      38498 non-null  object
#  2   region                   38498 non-null  object
#  3   region_url               38498 non-null  object
#  4   type                     38498 non-null  object
#  5   sqfeet                   38498 non-null  int64
#  6   beds                     38498 non-null  int64
#  7   baths                    38498 non-null  float64
#  8   cats_allowed             38498 non-null  int64
#  9   dogs_allowed             38498 non-null  int64
#  10  smoking_allowed          38498 non-null  int64
#  11  wheelchair_access        38498 non-null  int64
#  12  electric_vehicle_charge  38498 non-null  int64
#  13  comes_furnished          38498 non-null  int64
#  14  laundry_options          30643 non-null  object
#  15  parking_options          24493 non-null  object
#  16  image_url                38498 non-null  object
#  17  description              38498 non-null  object
#  18  lat                      38302 non-null  float64
#  19  long                     38302 non-null  float64
#  20  state                    38498 non-null  object
# dtypes: float64(3), int64(9), object(9)
# memory usage: 6.2+ MB
# None
# =======================================================
# ** Shape **
# Filas: 38498 - Columnas: 21
# =======================================================
# ** Describe - Estadísticas resumidas **
#                            count          mean           std           min  \
# id                       38498.0  7.040931e+09  8.783775e+06  7.004010e+09
# sqfeet                   38498.0  1.002063e+03  6.869335e+02  0.000000e+00
# beds                     38498.0  1.924749e+00  5.665451e+00  0.000000e+00
# baths                    38498.0  1.484129e+00  7.002277e-01  0.000000e+00
# cats_allowed             38498.0  7.276742e-01  4.451625e-01  0.000000e+00
# dogs_allowed             38498.0  7.084264e-01  4.544929e-01  0.000000e+00
# smoking_allowed          38498.0  7.320640e-01  4.428898e-01  0.000000e+00
# wheelchair_access        38498.0  8.338095e-02  2.764608e-01  0.000000e+00
# electric_vehicle_charge  38498.0  1.358512e-02  1.157623e-01  0.000000e+00
# comes_furnished          38498.0  4.800249e-02  2.137743e-01  0.000000e+00
# lat                      38302.0  3.722560e+01  5.502983e+00  4.253830e+00
# long                     38302.0 -9.265757e+01  1.635929e+01 -1.594200e+02
#
#                                   25%           50%           75%  \
# id                       7.035888e+09  7.043099e+09  7.048393e+09
# sqfeet                   7.500000e+02  9.470000e+02  1.150000e+03
# beds                     1.000000e+00  2.000000e+00  2.000000e+00
# baths                    1.000000e+00  1.000000e+00  2.000000e+00
# cats_allowed             0.000000e+00  1.000000e+00  1.000000e+00
# dogs_allowed             0.000000e+00  1.000000e+00  1.000000e+00
# smoking_allowed          0.000000e+00  1.000000e+00  1.000000e+00
# wheelchair_access        0.000000e+00  0.000000e+00  0.000000e+00
# electric_vehicle_charge  0.000000e+00  0.000000e+00  0.000000e+00
# comes_furnished          0.000000e+00  0.000000e+00  0.000000e+00
# lat                      3.347170e+01  3.761905e+01  4.114680e+01
# long                    -9.979000e+01 -8.785785e+01 -8.124207e+01
#
#                                   max
# id                       7.051284e+09
# sqfeet                   9.524200e+04
# beds                     1.100000e+03
# baths                    7.500000e+01
# cats_allowed             1.000000e+00
# dogs_allowed             1.000000e+00
# smoking_allowed          1.000000e+00
# wheelchair_access        1.000000e+00
# electric_vehicle_charge  1.000000e+00
# comes_furnished          1.000000e+00
# lat                      6.488100e+01
# long                     9.412480e+01
# =======================================================
# ** NaN - Nulos **
# id                             0
# url                            0
# region                         0
# region_url                     0
# type                           0
# sqfeet                         0
# beds                           0
# baths                          0
# cats_allowed                   0
# dogs_allowed                   0
# smoking_allowed                0
# wheelchair_access              0
# electric_vehicle_charge        0
# comes_furnished                0
# laundry_options             7855
# parking_options            14005
# image_url                      0
# description                    0
# lat                          196
# long                         196
# state                          0
# dtype: int64
# =======================================================
# ** Duplicated - Duplicados **
# 0

# %%
print_df_info(df_train)
# Out:
# ** Info - Información general **
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 346479 entries, 0 to 346478
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       346479 non-null  int64
#  1   url                      346479 non-null  object
#  2   region                   346479 non-null  object
#  3   region_url               346479 non-null  object
#  4   price                    346479 non-null  int64
#  5   type                     346479 non-null  object
#  6   sqfeet                   346479 non-null  int64
#  7   beds                     346479 non-null  int64
#  8   baths                    346479 non-null  float64
#  9   cats_allowed             346479 non-null  int64
#  10  dogs_allowed             346479 non-null  int64
#  11  smoking_allowed          346479 non-null  int64
#  12  wheelchair_access        346479 non-null  int64
#  13  electric_vehicle_charge  346479 non-null  int64
#  14  comes_furnished          346479 non-null  int64
#  15  laundry_options          275308 non-null  object
#  16  parking_options          219797 non-null  object
#  17  image_url                346479 non-null  object
#  18  description              346477 non-null  object
#  19  lat                      344757 non-null  float64
#  20  long                     344757 non-null  float64
#  21  state                    346479 non-null  object
# dtypes: float64(3), int64(10), object(9)
# memory usage: 58.2+ MB
# None
# =======================================================
# ** Shape **
# Filas: 346479 - Columnas: 22
# =======================================================
# ** Describe - Estadísticas resumidas **
#                             count          mean           std           min  \
# id                       346479.0  7.040988e+09  8.802214e+06  7.003808e+09
# price                    346479.0  9.664420e+03  4.703573e+06  0.000000e+00
# sqfeet                   346479.0  1.066326e+03  2.018537e+04  0.000000e+00
# beds                     346479.0  1.903189e+00  3.162685e+00  0.000000e+00
# baths                    346479.0  1.480339e+00  6.082459e-01  0.000000e+00
# cats_allowed             346479.0  7.268031e-01  4.456018e-01  0.000000e+00
# dogs_allowed             346479.0  7.078611e-01  4.547465e-01  0.000000e+00
# smoking_allowed          346479.0  7.317384e-01  4.430551e-01  0.000000e+00
# wheelchair_access        346479.0  8.197034e-02  2.743199e-01  0.000000e+00
# electric_vehicle_charge  346479.0  1.279154e-02  1.123742e-01  0.000000e+00
# comes_furnished          346479.0  4.814145e-02  2.140654e-01  0.000000e+00
# lat                      344757.0  3.723436e+01  5.550956e+00 -4.353330e+01
# long                     344757.0 -9.270541e+01  1.655107e+01 -1.638940e+02
#
#                                   25%           50%           75%  \
# id                       7.035988e+09  7.043325e+09  7.048431e+09
# price                    8.050000e+02  1.036000e+03  1.395000e+03
# sqfeet                   7.500000e+02  9.490000e+02  1.150000e+03
# beds                     1.000000e+00  2.000000e+00  2.000000e+00
# baths                    1.000000e+00  1.000000e+00  2.000000e+00
# cats_allowed             0.000000e+00  1.000000e+00  1.000000e+00
# dogs_allowed             0.000000e+00  1.000000e+00  1.000000e+00
# smoking_allowed          0.000000e+00  1.000000e+00  1.000000e+00
# wheelchair_access        0.000000e+00  0.000000e+00  0.000000e+00
# electric_vehicle_charge  0.000000e+00  0.000000e+00  0.000000e+00
# comes_furnished          0.000000e+00  0.000000e+00  0.000000e+00
# lat                      3.345310e+01  3.765010e+01  4.113790e+01
# long                    -1.007840e+02 -8.771080e+01 -8.117460e+01
#
#                                   max
# id                       7.051292e+09
# price                    2.768307e+09
# sqfeet                   8.388607e+06
# beds                     1.100000e+03
# baths                    7.500000e+01
# cats_allowed             1.000000e+00
# dogs_allowed             1.000000e+00
# smoking_allowed          1.000000e+00
# wheelchair_access        1.000000e+00
# electric_vehicle_charge  1.000000e+00
# comes_furnished          1.000000e+00
# lat                      1.020360e+02
# long                     1.726330e+02
# =======================================================
# ** NaN - Nulos **
# id                              0
# url                             0
# region                          0
# region_url                      0
# price                           0
# type                            0
# sqfeet                          0
# beds                            0
# baths                           0
# cats_allowed                    0
# dogs_allowed                    0
# smoking_allowed                 0
# wheelchair_access               0
# electric_vehicle_charge         0
# comes_furnished                 0
# laundry_options             71171
# parking_options            126682
# image_url                       0
# description                     2
# lat                          1722
# long                         1722
# state                           0
# dtype: int64
# =======================================================
# ** Duplicated - Duplicados **
# 0

# %%
df_test.parking_options.value_counts()
# Out:
# off-street parking    12890
# attached garage        4163
# carport                3907
# detached garage        1626
# street parking         1581
# no parking              306
# valet parking            20
# Name: parking_options, dtype: int64
